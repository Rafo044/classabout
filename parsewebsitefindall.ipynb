# %%
import requests as req
from bs4 import BeautifulSoup as bs
u=str(input("Pars olunacaq linki daxil edin : "))
k=req.get(u)
page=bs(k.content,'html.parser')
a=page.find_all()
# Out:
# <!DOCTYPE html>
#
# <html lang="az">
# <head>
# <meta charset="utf-8"/>
# <meta content="İşə düzəltmə şirkətləri axtarırsınızsa navigator.az-ın bu siyahısı sizin üçündür. Siyahı ilə tanış olmaq üçün keçid edin." name="description"/>
# <meta content="İşə Düzəltmə Mərkəzləri, ise duzeltme, ise duzeltme sirketleri, ise duzeltme xidmetleri" name="keywords"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">
# <meta content="https://navigator.az/az/scat/170/i̇she-duzeltme-shirketleri" property="og:url">
# <meta content="website" property="og:type">
# <meta content="İse Duzeltme Xidmetleri - İşə Düzəltmə Mərkəzləri" property="og:title"/>
# <meta content="İşə düzəltmə şirkətləri axtarırsınızsa navigator.az-ın bu siyahısı sizin üçündür. Siyahı ilə tanış olmaq üçün keçid edin." property="og:description"/>
# <meta content="https://navigator.az/assets/images/logo_fav.png" property="og:image"/>
# ...
