# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
trendyol='https://www.trendyol.com/sr?fl=trendyol-man---yeni-sezon-firsatlari'
geyim = req.get(trendyol)
print(geyim)
# Out:
# <Response [200]>

# %%
soup = bs(geyim.content, 'html.parser')

# %%
geyim = soup.find('div',{'class':"product-down"})
x = str(geyim)
print(x)
# Out:
# [<div class="product-down"><div><div class="prdct-desc-cntnr"><div class="prdct-desc-cntnr-ttl-w two-line-text"><span class="prdct-desc-cntnr-ttl" title="TRENDYOL MAN">TRENDYOL MAN</span><span class="prdct-desc-cntnr-name hasRatings" title="Lacivert Erkek Regular Fit Çizgili Dokuma Pijama Altı TMNAW23PJ00038">Lacivert Erkek Regular Fit Çizgili Dokuma Pijama Altı TMNAW23PJ00038</span></div></div></div><div class="ratings-container"><div class="ratings"><div class="star-w"><div class="empty"><div class="star"></div></div><div class="full" style="width:100%;max-width:100%"><div class="star"></div></div></div><div class="star-w"><div class="empty"><div class="star"></div></div><div class="full" style="width:100%;max-width:100%"><div class="star"></div></div></div><div class="star-w"><div class="empty"><div class="star"></div></div><div class="full" style="width:100%;max-width:100%"><div class="star"></div></div></div><div class="star-w"><div class="empty"><div class="star"></div></div><d
# ...

# %%
l=[]

# %%
l.append(x)

# %%
print(l)
# Out:
# ['TRENDYOL MANLacivert Erkek Regular Fit Çizgili Dokuma Pijama Altı TMNAW23PJ00038(28)134,99 TL']
