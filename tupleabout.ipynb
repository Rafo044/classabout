# %%
#Tuple
a=(122,988,55,77,12,1,2,5)
b=(25,88,'b','k')
d=(13,96,101,225,14)

# %%
#Tuple update
x=list(a)
y=list(b)

# %%
x[2]=92

# %%
x
# Out:
# [122, 988, 92, 77, 12, 1, 2, 5]

# %%
x.sort()

# %%
print(x)
# Out:
# [1, 2, 5, 12, 77, 92, 122, 988]

# %%
x.reverse()

# %%
print(x)
# Out:
# [988, 122, 92, 77, 12, 5, 2, 1]

# %%
a=(1,2,3)

# %%
print(a)
# Out:
# (1, 2, 3)

# %%
m={"grocery":"ickiler","fresh":"delicates"}

# %%
l=("MMC","QSA")

# %%
m['fresh']="fruits"

# %%
print(m)
# Out:
# {'grocery': 'ickiler', 'fresh': 'fruits'}
