# %%
login=str(input('mailinizi daxil edin'))
if login=='rafael':
  print('daxil oldunuz')
  parol=int(input('parolu daxil edin'))
  if parol==12345:
    print('parol dogrudur')
  else:
    print('parol yanlisdir')
else:
  print('error')
id=float(input('idinizi daxil edin'))
# Out:
# mailinizi daxil edinrafael
# daxil oldunuz
# parolu daxil edin12345
# parol dogrudur
# idinizi daxil edinhh
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-641d4bd82630> in <module>
#       9 else:
#      10   print('error')
# ---> 11 id=float(input('idinizi daxil edin'))
#
# ValueError: could not convert string to float: 'hh'

# %%
#kredit

# %%
ad=str(input('adiniz:  '))
soyad=str(input('soyad: '))
emekhaqqi=int(input('emekhaqqiniz'))
if emekhaqqi>400:
  print('kredit goture bilersiz')
else:
  print('kredit goture bilmersiz')
muddet=int(input('nece ayliq'))
if muddet==12:
  print(emekhaqqi*3)
# Out:
# adiniz:  rafael
# soyad: a.
# emekhaqqiniz500
# kredit goture bilersiz
# nece ayliq12
# 1500
