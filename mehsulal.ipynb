# %%
def medaxil():
  #alish=22
  satish=0
  #faiz=44
  kashlok=50
  sebet=[]
  yukle=int(input('Medaxili daxiol edin :'))
  balans=kashlok+yukle
  print(f"emeliyyat ugurla basha chatdi.Sizin balansiniz  : {balans}")
  #mehsullar=str(input('Almaq istediyiniz mehsulu secin: '))
  #print(f' Mehsullarin siyahisi  {mehsullar} ')
  x=str(input('Almaq istediyiniz mehsulu daxil edin  : '))
  if x=='a':
    print('Qiymeti : ',50)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':
      sebet.append('a')
      eded_sayi=int(input('Eded sayini daxil edin : '))
      k=balans-50*eded_sayi
      if k>=0:
        print(f'Satish  : {satish+50*eded_sayi}, Balans : {k}')
      else:
        print('Balansinizda kifayet qeder mebleg yoxdur ')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  elif x=='b':
    print('Qiymeti: ',42)
    almaq=str(input('Almaq isteyirsinizmi? '))
    eded_sayi=int(input('Eded sayini daxil edin : '))
    if almaq=='beli':
      sebet.append('b')
      print(f'Satish  : {satish+42} , Balans : {balans-42}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  elif x=='c':
    print('Qiymeti : ',55)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':
      sebet.append('a')
      print(f'Satish  : {satish+55} , Balans : {balans-55}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  elif x=='d':
    print('Qiymeti : ',38)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':
      sebet.append('a')
      print(f'Satish  : {satish+38} , Balans : {balans-38}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  else:
    print('Yanlish mehsul sechildi')

# %%
medaxil()
# Out:
# Medaxili daxiol edin :100
# emeliyyat ugurla basha chatdi.Sizin balansiniz  : 150
# Almaq istediyiniz mehsulu daxil edin  : a
# Qiymeti :  50
# Almaq isteyirsinizmi? beli
# Eded sayini daxil edin : 10
# Balansinizda kifayet qeder mebleg yoxdur
