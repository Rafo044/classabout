# %%
gmail=str(input('Email yaradin : '))
parol=int(input('Parol yaradin  : '))
gmail_baza=[]
parol_baza=[]
gmail_baza.append(gmail)
parol_baza.append(parol)
id=dict.fromkeys(gmail_baza,parol_baza)
print(f'Gmail ,Parol :{id}')
def girish():
  gmail_girish=str(input('Emailinizi daxil edin  :  '))
  for x in gmail_baza:
    if gmail_girish==x:
      parol_girish=int(input('Parolunuzu daxil edin  :  '))
      for y in parol_baza:
        if parol_girish==y:
          print('Daxil oldunuz  :  ')
          inbox=[]
          spam=[]
          sent=[]
          newmail=[]
          display('inbox' , 'spam' , 'sent' , 'newmail ')
          menu=str(input('Daxil olmaq istediyiniz sehifeni girin  : '))
          if menu=='inbox':
            print('Gelenler qutusu  ')
          elif menu=='spam':
            print(' Spam qutusu ')
          elif menu=='sent':
            print(' Gonderilenler qutusu ')
          elif menu=='newmail':
            print(' Yeni email yaradin :  ')
            user01=[]
            user02=[]
            user03=[]
            print('User01,  User02  ,User03 ')
            kime=str(input(' Mesaji gomdermmek istediyiniz shexsi qeyd edin :  '))
            mesaj=str(input(' Mesaji daxil edin  :'))
            for l in mesaj:
              if l=='k':
                spam.append(l)
                print('Mesajiniz dogru deyil')
              else:
                print('Mesajiniz gonderildi')
            if kime=='user01':
              user01.append(mesaj)
            elif kime=='user02':
              user02.append(mesaj)
            elif kime=='user03':
              user03.append(mesaj)
            else:
              print('Yanlish shexsi secdiniz')
          else:
            print('Yanlish menu secimi')
        else:
          print('Yanlish parol')
    else:
        print('Yanlish email adresi')
# Out:
# Email yaradin : a
# Parol yaradin  : 1
# Gmail ,Parol :{'a': [1]}

# %%
girish()
# Out:
# Emailinizi daxil edin  :  a
# Parolunuzu daxil edin  :  1
# Daxil oldunuz  :
# 'inbox'
# 'spam'
# 'sent'
# 'newmail '
# Daxil olmaq istediyiniz sehifeni girin  : newmail
#  Yeni email yaradin :
# User01,  User02  ,User03
#  Mesaji gomdermmek istediyiniz shexsi qeyd edin :  user01
#  Mesaji daxil edin  :k
# Mesajiniz dogru deyil
