# %%
import pandas as pd
import numpy as np
import re
import requests as req

# %%
url = pd.read_html('https://en.wikipedia.org/wiki/List_of_most_valuable_brands')

# %%
df=df01 = url[0]
df02 = url[1]
df03 = url[2]

# %%
df04 = url[4]

# %%
df05 = url[5]

# %%
df05
# Out:
#    Rank             Brand        Country  Brand value(US$ millions)  Rank.1  \
# 0     1         Coca-Cola  United States                      72537      11
# 1     2         Microsoft  United States                      70196      12
# 2     3               IBM  United States                      53183      13
# 3     4             Intel  United States                      39048      14
# 4     5             Nokia        Finland                      38528      15
# 5     6  General Electric  United States                      38127      16
# 6     7              Ford  United States                      36368      17
# 7     8       Walt Disney  United States                      33553      18
# 8     9        McDonald's  United States                      27859      19
# 9    10              AT&T  United States                      25548      20
#
#             Brand.1      Country.1  Brand value(US$ millions).1
# 0          Marlboro  United States                        22110
# ...

# %%
df05[0:4][['Brand','Country']]
# Out:
#        Brand        Country
# 0  Coca-Cola  United States
# 1  Microsoft  United States
# 2        IBM  United States
# 3      Intel  United States

# %%
df05[4:5]
# Out:
#    Rank  Brand  Country  Brand value(US$ millions)  Rank.1 Brand.1 Country.1  \
# 4     5  Nokia  Finland                      38528      15  Toyota     Japan
#
#    Brand value(US$ millions).1
# 4                        18823

# %%
data = pd.read_excel('/content/LF51 - Super Price 16 - (08 December - 21 December) - LEAFLET.xlsx')

# %%
data
# Out:
#     PROMO INFORMATION: LF 51 - Super Price 16 - (08 December - 21 December) - LEAFLET  \
# 0                                        COMPLATE INFO
# 1                                            Completed
# 2                                            Completed
# 3                                            Completed
# 4                                            Completed
# ..                                                 ...
# 992                                                NaN
# 993                                                NaN
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
#
#        Unnamed: 1      Unnamed: 2            Unnamed: 3     Unnamed: 4  \
# 0    PAGE\nNUMBER  PRODUCT NUMBER  Family Code (Choose)  Supplier Code
# 1          PAGE 1               1                   F01         AZE168
# ...
