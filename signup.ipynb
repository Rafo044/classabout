# %%
a=11
b=12

# %%
class wolt:
  def __init__(self,kuryer):
    self.kuryer=kuryer
  def girish(self):
    print(self.kuryer)
    ad=str(input('Adinizi daxil edin : '))
    soyad=str(input('Soyadinizi daxil edin : '))
    tevellud=int(input('Dogum ilinizi qeyd edin :'))
    il=2023
    shifre=str(input('Shifre daxil edin(6 herif) :'))
    if len(shifre)==6:
      print(f"Shifre teyin edildi  : {shifre} ")
    else:
      print('Shifre yalniz 6 herif olmalidir .')
    if tevellud<2023 and tevellud>1950:
      yash=il-tevellud
      print(f"Ad : {ad} , Soyad : {soyad}, yash : {yash}, Shifre : {shifre}")
    else:
      print("Dogum ilinizi duzgun qeyd etmediniz .")
  def sira_nomresi(self):
    novbe=[]
    print('Sira nomresi secin : ')
    for sira_nomresi in range(1,21):
      while sira_nomresi<5:
        print('Ilk siralarda sizsiniz')
        novbe.append(sira_nomresi)
        if sira_nomresi>3:
          print('Sizin sira nomreniz 4 dur.')
        else:
          print('Sira nomreniz 4den kicikdir.')
        break
  def restoranlar(self):
    a=['mcdonals','papajohns','kfc']
    display(a)
    restoran=str(input('Restoranin adini daxil edin : '))
    if restoran=='mcdonals':
      x=['narimanov','genclik','Sahil']
      display(x)
    elif restoran==a[2]:
      x=['narimanov','genclik','Sahil']
      display(x)
    elif restoran==a[3]:
      x=['narimanov','genclik','Sahil']
      display(x)
    else:
       print('Duzgun restoran secmediniz .')
  def yemekler(self):
    yemek=str(input('Arzuladiziniz yemeki daxil edin :'))
    sebet=[]
    sebet.append(yemek)
    print(sebet)

# %%
a=wolt('rafael')

# %%
a.girish()
# Out:
# rafael
# Shifre yalniz 6 herif olmalidir .
# Ad : rafael , Soyad : alixanli, yash : 22, Shifre : R1254

# %%
a.restoranlar()
# Out:
# ['mcdonals', 'papajohns', 'kfc']
# Restoranin adini daxil edin : kfc
# ['narimanov', 'genclik', 'Sahil']

# %%
a.yemekler()
# Out:
# Arzuladiziniz yemeki daxil edin :as
# ['as']
