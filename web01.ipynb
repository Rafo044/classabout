# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
k='https://www.navigator.az/'
n = req.get(k)
print(n)
# Out:
# <Response [200]>

# %%
soup = bs(n.content, 'html.parser')

# %%
n = soup.find('div',{'class':"converter__wrap"}).text
m = str(n)
print(m)
# Out:
# Valyuta Konvertoru
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bütün valyutalar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AZN
#
#
#
# TL
#
#
#
# USD
#
#
#
# EUR
#
#
#
# RUB

# %%
l=[]

# %%
type(m)
# Out:
# str

# %%
l.append(m)

# %%
print(l)
# Out:
# ['\n\nValyuta Konvertoru\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\n\nBütün valyutalar\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\n\n\n\n\n\nAZN\n\n\n\nTL\n\n\n\nUSD\n\n\n\nEUR\n\n\n\nRUB\n\n\n\n']
