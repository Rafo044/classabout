# %%
# Full name ,Las Name,Email adress,Sosial Media,Phone number

# %%
import pandas as pd

# %%
df = pd.read_html('https://www.zillow.com/professionals/real-estate-agent-reviews/boulder-co/?page=22',attrs = {'class':"StyledTableHeader-c11n-8-50-1__sc-1ba0xxh-0 kvUHlh"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8e51c9196979> in <cell line: 1>()
# ----> 1 df = pd.read_html('https://www.zillow.com/professionals/real-estate-agent-reviews/boulder-co/?page=22',attrs = {'class':"StyledTableHeader-c11n-8-50-1__sc-1ba0xxh-0 kvUHlh"})
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import re

# %%
url='https://www.zillow.com/professionals/real-estate-agent-reviews/boulder-co/?page=22'
page = req.get(url)
print(page)
# Out:
# <Response [200]>

# %%
p = bs(page.content, 'html.parser')

# %%
table =p.find("tbody", attrs = { "class" : "StyledTable-c11n-8-50-1__sc-b979s8-0 eSCkQe" })

# %%
print(table)
# Out:
# None

# %%
print(a)
# Out:
# []

# %%
b=[]
for y in p.findAll('',{'class':"middle"}):
  #print(y.text)
  s=re.sub('AZN','',y.text)
  e=re.sub(' ','',s)
  e=int(e)
  #print(e)
  b.append(e)

# %%
telefon=dict(zip(a,b)) 
telefon
# Out:
# {'Apple iPhone 13 Pro Sierra Blue 128GB/6GB': 1700}

# %%
telefonlar={}
url='https://tap.az/elanlar/elektronika/telefonlar/34566773'
page = req.get(url)
print(page)
for x in p.findAll('h1',{'class':"js-lot-title"}):
  for y in p.findAll('div',{'class':"middle"}):
    #print(y.text)
    s=re.sub('AZN','',y.text)
    e=re.sub(' ','',s)
    e=int(e)
    telefonlar.update({x.text:e})
display(telefonlar)
# Out:
# <Response [200]>
# {'Apple iPhone 13 Pro Sierra Blue 128GB/6GB': 1700}

# %%
for x in p.findAll(attrs={'class':"StyledTableHeader-c11n-8-50-1__sc-1ba0xxh-0 kvUHlh"}):
  print(x.text)

# %%
for x in p.findAll('div',{'class':"StyledTableHeader-c11n-8-50-1__sc-1ba0xxh-0 kvUHlh"}):
  print(x)

# %%
x
# Out:
# []

# %%
a=[]
x=p.find(attrs={'class':"table_table"}).text
a.append(x)
display(a)

# %%
import requests as req                 #sorgu gonderib geri donush 
from bs4 import BeautifulSoup as bs    #Bu bize html ve ya bashqa hansisa shablonlarda olan kdodlari 
u='https://lalafo.az/'
page = req.get(u)
soup = bs(page.content, 'html.parser')
for x in soup.findAll('div',{'class':"adTile-mainInfo"}):  
  #print(x)
  for y in soup.findAll('a',{'class':"adTile-mainInfo-link"}):
     a='www.lalafo.az'+y.get('href')
     #print(a)
  for w in soup.findAll('h1',{'class':"Heading secondary-small "}):
    print(w.text)

# %%
for x in p.findAll('div',{'class':"adTile-mainInfo"}):
  #print(x)
  for y in p.findAll('a',{'class':"adTile-mainInfo-link"}):
    #print(y.get('href'))
    a=u+y.get('href')
    # o=re.sub('//','/',a)
    # print(o)

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd
a=[]
b=[]
u='https://kontakt.az/telefonlar/mobil-telefonlar/xiaomi-mobil-telefonlar/'
page = req.get(u)
soup = bs(page.content, 'html.parser')
for x in soup.findAll(attrs={'draggable':"false"}):
    r=re.sub('\n','',x.text)
    a.append(r)
for z in soup.findAll(attrs={'class':"nprice"}):
    t=re.sub(' M','',z.text)
    s=float(t)
    b.append(s)
    d=dict(zip(a,b))
#display(d)
df=pd.Series(d)
display(df)
a=df.to_csv('kontakt home data.csv')


mehsul=input('Mehsulun adini daxil edin: ')
for k,v in d.items():
  if k==mehsul:
    say=int(input('Nece eded isteyirsiniz? '))
    total=say*v
print('Sizin borcunuz: ',total)
# Out:
# Xiaomi Poco X5 Pro 5G 8/256 GB Black                   899.99
# Xiaomi Poco X5 5G 8/256 GB Green                        53.80
# Xiaomi Poco X5 5G 8/256 GB Blue                        699.99
# Xiaomi Poco X5 5G 8/256 GB Black                        41.80
# Xiaomi 13 Lite 8/256 GB Black                          699.99
# Xiaomi 13 Lite 8/128 GB Black                           41.80
# Xiaomi Redmi 10A 2/32 GB Sky Blue                      699.99
# Xiaomi Redmi Note 11 Pro 5G 6GB/64GB Polar White        41.80
# Xiaomi Redmi Note 11 Pro 5G 6/64 GB Atlantic Blue     1099.99
# Xiaomi Redmi A1+ 2/32 GB Light Blue                     65.70
# Xiaomi 12T 8/128 GB Silver                            1029.99
# Xiaomi 12T 8/256 GB Silver                              61.50
# Xiaomi 11 T 8/128 GB Moonlight White                   299.99
# Xiaomi Poco M5 4/128 GB Black                           17.90
# Xiaomi 12 Lite 8/256 GB Green                          749.99
# ...

# %%
342325364f=open('data.csv','w')
f.write(data)
f.close
# Out:
#   File "<ipython-input-13-68b459fb3a91>", line 1
#     342325364f=open('data.csv','w')
#              ^
# SyntaxError: invalid syntax

# %%
s=data.read_to_csv('Data.csv')

# %%
a=[1,2,3,4,5,6,7,8,9]

# %%
print(len(a))
# Out:
# 9

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import re
a=[]
b=[]
sum=0
u='https://kontakt.az/telefonlar/mobil-telefonlar/'
page = req.get(u)
soup = bs(page.content,'html.parser')
for x in soup.findAll(attrs={'draggable':"false"},limit=3):
    r=re.sub('\n','',x.text)
    a.append(r)
for y in soup.findAll(attrs={'class':"gridprice gridprice_cash"},limit=3):
    b.append(y.text)
    d=dict(zip(a,b))
display(d)

n=int(input('Nece eded mehsul gotereceksen? '))
for f in range(n):
  mehsul=str(input('mehsulu daxil edin: '))
  for i in d.keys():
    if i == mehsul:
      say=int(input('Nece eded isteyirsiniz? '))
      qiymet=float(input('Qiymet: '))
      total=say*qiymet
      sum+=total
print(sum)
# Out:
# {'Samsung Galaxy A13 DS (SM-A135) 64 GB Black ': '399.99 M',
#  'Xiaomi Redmi Note 11 4/128 GB Twilight Blue ': '679.99 M',
#  'Samsung Galaxy S22 (SM-S901B) Phantom Black ': '399.99 M'}
# Nece eded mehsul gotereceksen? 1
# mehsulu daxil edin: Samsung Galaxy S22 (SM-S901B) Phantom Black
# Nece eded isteyirsiniz? 2
# Qiymet: 23
# 46.0

# %%
mehsul=str(input('mehsulu daxil edin: '))
if mehsul==d.keys():
  say=int(input('Nece eded isteyirsiniz? '))
  qiymet=int(input('Qiymet: '))
  total=say*qiymet
  sum+=total
print(sum)
# Out:
# mehsulu daxil edin: \nSamsung Galaxy S22 (SM-S901B) Phantom Black
# 0

# %%
d
# Out:
# {'\nSamsung Galaxy A13 DS (SM-A135) 64 GB Black ': '399.99 M',
#  '\nXiaomi Redmi Note 11 4/128 GB Twilight Blue ': '679.99 M',
#  '\nSamsung Galaxy S22 (SM-S901B) Phantom Black ': '399.99 M'}

# %%
d.keys()
# Out:
# dict_keys(['\nSamsung Galaxy A13 DS (SM-A135) 64 GB Black ', '\nXiaomi Redmi Note 11 4/128 GB Twilight Blue ', '\nSamsung Galaxy S22 (SM-S901B) Phantom Black '])

# %%
d.items()
# Out:
# dict_items([('\nSamsung Galaxy A13 DS (SM-A135) 64 GB Black ', '399.99 M'), ('\nXiaomi Redmi Note 11 4/128 GB Twilight Blue ', '679.99 M'), ('\nSamsung Galaxy S22 (SM-S901B) Phantom Black ', '399.99 M')])

# %%
stok={}
ul='https://turbo.az/'
p=req.get(ul)
print(p)
s=bs(p.content,'html.parser')
# Out:
# <Response [200]>

# %%
for x in s.findAll(attrs={'class':"products-i_name products-i_bottom-text"}):
  print(x.text)
# Out:
#   File "<ipython-input-79-865b2e028245>", line 1
#     for x in s.findAll(attrs={'class':"products-i_name products-i_bottom-text"}):
#              ^
# SyntaxError: invalid character in identifier

# %%
import requests as req
from bs4 import BeautifulSoup as bs
u='https://navigator.az/az/firm/31244/baki-olimpiya-stadionu-kovorkinq'
page=req.get(u)
soup=bs(page.content, 'html.parser')
# Out:
#   File "<ipython-input-5-d40bfa7ebd2a>", line 5
#     soup=bs(page.content, 'html.parser')
#                          ^
# SyntaxError: invalid character in identifier

# %%
for x in soup.findAll(attrs={'class':"products-i_name products-i_bottom-text"}):
  print(x.text)
# Out:
#   File "<ipython-input-6-962a6dbfccbb>", line 1
#     for x in soup.findAll(attrs={'class':"products-i_name products-i_bottom-text"}):
#                 ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd

# %%
a=pd.read_csv('/content/trend (1).csv')
display(a)
# Out:
#     Kahverengi Yaka Detaylı Örme Elbise TPRSS22EL1295   87.99  TL
# 0          Siyah Balenli Dokuma Elbise TPRAW23EL00175  236.99  TL
# 1         Mor-Çok Renkli Tek Kol Elbise TPRSS21EL0179  110.99  TL
# 2   Limited Edition Siyah Kemerli Suni Deri Elbise...  399.99  TL
# 3   Kahverengi Kuşaklı Dantel Detaylı Gömlek Elbis...  241.99  TL
# 4    Kırmızı Bel Detaylı Dokuma Elbise TPRAW23EL00027  142.99  TL
# 5   Camel Yaka Detaylı Pötikareli Elbise TWOAW22EL...  235.99  TL
# 6           Açık Mor Bel Detaylı Elbise TPRSS21EL1398  159.99  TL
# 7                  Bordo Kemerli Elbise TWOAW22EL0243  273.99  TL
# 8         Siyah Aksesuar Detaylı Elbise TPRSS20EL2061  242.99  TL
# 9         Tarçın Eteği Asimetrik Elbise TPRSS22EL2882  100.99  TL
# 10     Kahverengi Düğme Detaylı Elbise TWOAW23EL00427  271.99  TL
# 11  Lacivert Çıtçıtlı Kare Yaka Örme Elbise TWOAW2...  125.99  TL
# 12                Mürdüm V Yaka Elbise TWOAW23EL00352  240.99  TL
# ...

# %%
# Out:
# Adi daxil edin: BIBWQE
# Adi daxil edin: AEKF
# Adi daxil edin: aefkae
# Adi daxil edin: adef
# Adi daxil edin: aeksfk
# {}

# %%
class parsing:
  def __init__(self,a=[]):
    self.a=a
    def navugator(self):
      import requests as req
      from bs4 import BeautifulSoup as bs
      =0
      baza={}
      for o in range(2):
        url=str(input('Url-i daxil edin : '))
        p=req.get(url)
        soup=bs(p.content,'html.parser')
        ad=soup.find('h1',{'class':"company-name"}).text.strip()
        adress=soup.find('p',{'itemprop':'address'}).text.strip()
        nomre=soup.find('p',{'itemprop':'telephone'}).text.strip()
        baza.update({ad:[adress,nomre]})
        i+=1
        i
        a.append(i)
      def kontak(self):


      def trendyol(self):
# Out:
# Url-i daxil edin : https://navigator.az/az/firm/31217/khalili-plaza-
# Url-i daxil edin : https://navigator.az/az/firm/31205/aral-plaza

# %%
display(baza)
# Out:
# {'KHALILI PLAZA': ['Bakı, Nərimanov r-nu, Əhməd Rəcəbli 19A',
#   '(+99455) 250-34-54'],
#  'ARAL PLAZA': ['Bakı, Nərimanov r-nu, Atatürk pr. 118A-120',
#   '(+994 50) 268-22-69 (+994 51) 207-07-52']}

# %%
for z in soup.findAll('div',{'data-testid':"ad-price-value"},'span'):
  print(z.text)
# Out:
# 53 700.ooa-17thm23{padding-left:4px;font-size:10px;line-height:20px;}PLN

# %%
import requests as req
from bs4 import BeautifulSoup
url = "https://www.expansion.com/empresas-de/ganaderia/granjas-en-general/index.html"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
lists = soup.select("div#simulacion_tabla ul")

for lis in lists:
    title = lis.find('li', class_="col1").text
    location = lis.find('li', class_="col2").text
    province = lis.find('li', class_="col3").text
    info = [title, location, province]

# %%
info
# Out:
# ['AGRICOLA CALLEJA SL', 'CARPIO', 'VALLADOLID']

# %%
import requests
from bs4 import BeautifulSoup
for page in range(0,1005):
    url = "https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate".format(page =page)
    #print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    lists = soup.select("div#simulacion_tabla ul")

    for lis in lists:
        title = lis.find('', class_="col1").text
        location = lis.find('li', class_="col2").text
        province = lis.find('li', class_="col3").text
        info = [title, location, province]
        print(info)

# %%
import requests
from bs4 import BeautifulSoup

for i in range(0, 5, 1):
    url = f'https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page={i}'

    req = requests.get(url)
    result = req.content
    # print(url)
    print(result)

a=[]
b=[]
LINK=input('input url')
page = req.get(LINK)
soup = BeautifulSoup(page.content,'html.parser')
for x in soup.findAll(attrs={'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
    a.append(x.text)
    print(a)
    # for x in range(len(a)):
    #   c=int(input('sayi daxil edin:'))
    #   b.append(c)
    #   break
#     baza=dict(zip(a,b))
# display(baza)

# %%
import requests
from bs4 import BeautifulSoup

for i in range(0, 5, 1):
    url = f'https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page={i}'

    req = requests.get(url)
    result = req.content
    print(url)
# Out:
# https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practi
# ...

# %%
html = 'https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page=0'

soup = BeautifulSoup(html)

for a in soup.find_all('a', href=True):
    print("Found the URL:", a['href'])

# %%
import requests as req               #sorgu gonderib geri donush 
from bs4 import BeautifulSoup as bs  #Bu bize html ve ya bashqa hansisa shablonlarda olan kdodlari 
u='https://lalafo.az/'
page = req.get(u)
soup = bs(page.content, 'html.parser')

for x in soup.findAll('div',{'class':"adTile-mainInfo"}):
  #print(x)
  for y in soup.findAll('a',{'class':"adTile-mainInfo-link"}):
    a='https://lalafo.az'+y.get('href')
    print(a)
    for z in soup.findAll(attrs={'class':"Heading secondary-small "}):
        print(z.text)
# Out:
# https://lalafo.az/baku/ads/masa-oturacaq-desti-id-87430007
# https://lalafo.az/baku/ads/yoshiro-smart-tv-tezedi-az-islenib-tam-islekdi-prablemi-yoxdu-82-id-77872119
# https://lalafo.az/baku/ads/riyaziyyat-toplu-1ci-hiss-id-99108174
# https://lalafo.az/baku/ads/elani-screen-edib-watcapa-gonderin-id-78721992
# https://lalafo.az/baku/ads/endirimle-son-1-gun-qaldi-sifarisl-masa-dsti-6-nfrlik-520-id-93166268
# https://lalafo.az/baku/ads/dstlr-id-94759915
# https://lalafo.az/baku/ads/su-aparati-sok-aparati-sirali-su-aparati-id-86059806
# https://lalafo.az/baku/ads/islnmyibqutusundadirkecmisin-dstidir-id-98299568
# https://lalafo.az/baku/ads/riyaziyyat-toplu-2ci-hiss-id-93449230
# https://lalafo.az/zejnalabdin-tagiev/ads/telefon-gul-kimi-iwleyir-almaniyadan-gelib-geydiyattan-kecib-iwlemeyne-id-106795946
# https://lalafo.az/baku/ads/salam-mn-elektron-kitab-satiram-kontakt-homdan-350-manata-id-103467805
# ...

# %%
import requests as req               #sorgu gonderib geri donush 
from bs4 import BeautifulSoup as bs  #Bu bize html ve ya bashqa hansisa shablonlarda olan kdodlari 
import re                            #RegEx
u='https://lalafo.az/'
page = req.get(u)
soup = bs(page.content, 'html.parser')

for x in p.findAll('div',{'class':"adTile-mainInfo"}):
  #print(x)
  for y in p.findAll('a',{'class':"adTile-mainInfo-link"}):
    a='https://lalafo.az'+y.get('href')
    print(a)
    s = req.get(a)
    p = bs(page.content, 'html.parser')
    for z in p.findAll(attrs={'class':"Heading secondary-small "}):
      print(z.text)
# Out:
# https://lalafo.az/baku/ads/cin-nagd-odnis-yeni-id-94905434
# https://lalafo.az/baku/ads/klassik-yataq-desti-1900-azn-yaxsi-veziyyetdedir-matrasi-var-7000-id-105978586
# https://lalafo.az/novkkhani/ads/yataw-desti-seliqeli-veziyyatda-400-azn-sumqayit-samire-sum-id-84261797
# https://lalafo.az/baku/ads/metbex-mebeli-olcu-360-texmini-uzerinde-qaz-moyka-asbirator-verilir-id-105978394
# https://lalafo.az/baku/ads/az-islenmis-soyuducu-zemanetle-satlir-cesidlerimiz-coxdur-id-76358357
# https://lalafo.az/novkkhani/ads/1-defe-geyinlib-razmer-boyukdu-diye-satilir-10-manata-id-105977799
# https://lalafo.az/baku/ads/endirim-divan-ve-2-kreslo-birlikde-300-azn-yaxsi-veziyyetdedir-id-85812722
# https://lalafo.az/baku/ads/unvan-gunesli-salon-deil-evdir-id-78075659
# https://lalafo.az/baku/ads/usaqlar-ucun-digr-mallar-id-83398681
# https://lalafo.az/novkkhani/ads/yataq-desti-tcili-satilir-hecbir-problemi-yoxdur-deste-daxildir-id-105979321
# ...

# %%
from bs4 import BeautifulSoup
import requests
for a in range(2):
  url = 'https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page={i}'

  req = requests.get(url)
  result = req.content
  #print(url)
  soup=BeautifulSoup(req.content,"html.parser")
  for x in soup.findAll('div',{'class':"field field--name-name field--type-string field--label-hidden field--item"}):
    for l in x:
      print('https://www.step.org/'+l.get('href'))
      page = requests.get('https://www.step.org/'+l.get('href'))
      soup = BeautifulSoup(page.content,'html.parser')
      for x in soup.findAll('div',{'class': "field field--name-name field--type-string field--label-hidden field--item"}):
        print(x.text)
# Out:
# https://www.step.org//directory/members/mr-darragh-mccarthy-0033c00002uunyuaa3
# Mr Darragh McCarthy
# https://www.step.org//directory/members/mr-darin-donovan-003c000001gtnlviaf
# Mr Darin Donovan
# https://www.step.org//directory/members/mr-bobby-brantley-003c0000014qae6iai
# Mr Bobby Brantley
# https://www.step.org//directory/members/miss-laura-kyle-0038000000gio9jaae
# Miss Laura Kyle
# https://www.step.org//directory/members/mr-john-chew-0038000000gim5jaae
# Mr John Chew
# https://www.step.org//directory/members/mr-david-marks-0038000000gioauaae
# Mr David Marks
# https://www.step.org//directory/members/mr-alain-gass-0038000000gin4yaau
# Mr Alain Gass
# https://www.step.org//directory/members/mr-christopher-wallworth-0038000000giqo4aae
# Mr Christopher Wallworth
# https://www.step.org//directory/members/senor-fernando-elias-0038000000gimjbaae
# ---------------------------------------------------------------------------
# ...

# %%
url ='https://boss.az/vacancies?search%5Bcategory_id%5D=39'
req = requests.get(url)
result = req.content
#print(url)
soup=BeautifulSoup(req.content,"html.parser")
for x in soup.findAll('a',{'class':"results-i-company"}):
    print('https://boss.az/'+x.get('href'))
    page = requests.get('https://boss.az/'+x.get('href'))
    soup = BeautifulSoup(page.content,'html.parser')
    for x in soup.findAll(attrs={'class':"results-i-salary salary"}):
      print(x.text)
# Out:
# https://boss.az//vacancies?search%5Bcompany_id%5D=63129
# 800 - 1000 AZN
# https://boss.az//vacancies?search%5Bcompany_id%5D=61499
# 800 - 1000 AZN
# https://boss.az//vacancies?search%5Bcompany_id%5D=60529
# 3000 - 3500 AZN
# 3000 - 3500 AZN

# %%
page = requests.get(l)
soup = BeautifulSoup(page.content,'html.parser')
for x in soup.findAll(attrs={'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
  print(x.text)
# Out:
# Mrs Vanessa Schrum

# %%
for link in soup.findAll('a'):
    print(link.get('href'))

# %%
for x in soup.findAll('div',{'class':"field field--name-name field--type-string field--label-hidden field--item"}):
  for l in x:
    print('https://www.step.org/'+l.get('href'))
    # print(l.get('href'))

  
  # print(x)
# page = requests.get(l)
# soup = BeautifulSoup(page.content,'html.parser')
# for x in soup.findAll(attrs={'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
#     print(x.text)
# Out:
# https://www.step.org//directory/members/mr-damien-jones-0038000000ginusaau
# https://www.step.org//directory/members/mr-richard-tutty-0038000000giqfuaae
# https://www.step.org//directory/members/mr-charles-richardson-003c000001gs95biar
# https://www.step.org//directory/members/mrs-merilyn-steele-003c0000022ersziae
# https://www.step.org//directory/members/ms-kathy-strobl-003c000001dnshriae
# https://www.step.org//directory/members/mrs-monica-ross-maranik-003c000001fy0smiay
# https://www.step.org//directory/members/mrs-jane-lynch-003c0000014qfydiau
# https://www.step.org//directory/members/ms-michele-allinotte-003c000002oa7t6ial
# https://www.step.org//directory/members/ms-faye-kravetz-0033c00002hcyifaa4
# https://www.step.org//directory/members/miss-sijin-chen-0033c00002zvxsraa5

# %%
data={}
for i in range(0,2,1):
    url = 'https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page={i}'

    req = requests.get(url)
    result = req.content
    #print(url)
    soup=BeautifulSoup(req.content,"html.parser")
    a=[]
    for x in soup.findAll('div',{'class':"field field--name-name field--type-string field--label-hidden field--item"}):
      for l in x:
        #print('https://www.step.org/'+l.get('href'))
        page = requests.get('https://www.step.org/'+l.get('href'))
        soup = BeautifulSoup(page.content,'html.parser')
        for x in soup.findAll(attrs={'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
          print(x.text)
        for y in soup.findAll(attrs={'class':""}):
          print(y.text.replace('\n',''))
          data.setdefault(x.text,y.text.replace('\n',''))

            # def cfDecodeEmail(encodedString):
            #   r = int(encodedString[:2],16)
            #   email = ''.join([chr(int(encodedString[i:i+2],16) ^ r) for i in range(2, len(encodedString),16)])
            #   return email

            # print(cfDecodeEmail('3e5f504a56515047105251495b4d7e4d4a53594c514b4e4e525d105d5153'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-142dd23b4588> in <cell line: 2>()
# ...

# %%
 data
# Out:
# {'Mr Anthony Lowes': 'Profession:Estate PlannerLawyer/Solicitor/AttorneyTrustee/FiduciaryTrust Officer',
#  'Mr Mike Cheung': 'Profession:Wealth Management',
#  'Mr John Lupton': 'Profession:AccountantTax Advisor',
#  'Miss Emma Facey': 'Profession:Lawyer/Solicitor/Attorney',
#  'Ms Myriam Zadra': 'Profession:Lawyer/Solicitor/AttorneyTrustee/FiduciaryNotaryTrust OfficerWealth ManagementCorporate Administrator',
#  'Ms Cynthia Kett': 'Profession:AccountantEstate PlannerFinancial PlannerTax AdvisorTrustee/Fiduciary',
#  'Mr Tomasz Hatylak': 'Profession:Tax Advisor',
#  'Mr Ian Walker': 'Profession:Lawyer/Solicitor/Attorney',
#  'Ms Susanne Batchelor': 'Profession:Lawyer/Solicitor/Attorney',
#  'Mr Stanley Foodman': 'Profession:Accountant'}

# %%
import requests
from bs4 import BeautifulSoup
import re

# Send a GET request to the website
url = "https://www.example.com"
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the email element and extract the encoded email
encoded_email = soup.find("div", {"class": "field--type-email"}).a.text

# Decode the email using a regular expression pattern
decoded_email = re.sub(r"\[at\]", "@", encoded_email)
decoded_email = re.sub(r"\[dot\]", ".", decoded_email)

# %%
for i in range(0,2,1):
    url = 'https://www.step.org/directory/members/search?name=&fgeolocation_members=&autocomplete=&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page={i}'
    req = requests.get(url)
    result = req.content
    #print(url)
    soup=BeautifulSoup(req.content,"html.parser")
    a=[]
    data={}
    for x in soup.findAll('div',{'class':"field field--name-name field--type-string field--label-hidden field--item"}):
      for l in x:
        #print('https://www.step.org/'+l.get('href'))
        page = requests.get('https://www.step.org/'+l.get('href'))
        soup = BeautifulSoup(page.content,'html.parser')
        for x in soup.findAll(attrs={'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
          print(x.text)
        for y in soup.findAll(attrs={'class':"field-item field-label-inline"}):
          a.append(y.text.replace('\n',''))
        for z in soup.findAll(attrs={'class':'country'}):
          print(z.text) 
          a.append(z.text) 
          #data.setdefault(x.text,a)
          data.update({x.text:a})
# Out:
# Mr Barry Mitchell
# Hong Kong
# Hong Kong
# Miss Katie Gibson-Green
# United Kingdom
# United Kingdom
# Ms Sarah Clowes
# United Kingdom
# United Kingdom
# Mr Alejandro Garcia
# Mexico
# Mexico
# Mrs Sarah Parker
# United Kingdom
# United Kingdom
# Ms Barbara Stephens
# United Kingdom
# United Kingdom
# Mrs Nadia Bechai
# Canada
# Canada
# Miss Frances White
# United Kingdom
# United Kingdom
# Mr Nigel Sims
# United Kingdom
# United Kingdom
# Mr Giuseppe Macaluso
# Switzerland
# Switzerland
# Mr Barry Mitchell
# Hong Kong
# Hong Kong
# Miss Katie Gibson-Green
# United Kingdom
# United Kingdom
# Ms Sarah Clowes
# United Kingdom
# United Kingdom
# Mr Alejandro Garcia
# Mexico
# Mexico
# Mrs Sarah Parker
# United Kingdom
# United Kingdom
# Ms Barbara Stephens
# United Kingdom
# United Kingdom
# Mrs Nadia Bechai
# Canada
# Canada
# Miss Frances White
# United Kingdom
# United Kingdom
# Mr Nigel Sims
# United Kingdom
# United Kingdom
# Mr Giuseppe Macaluso
# Switzerland
# Switzerland

# %%
data
# Out:
# {'Mr Barry Mitchell': ['Profession:Lawyer/Solicitor/Attorney',
#   'Firm:BGA Law (Hong Kong) LLP',
#   'Branch/chapter:STEP Hong Kong',
#   'Hong Kong',
#   'Hong Kong',
#   'Profession:Lawyer/Solicitor/Attorney',
#   'STEP Qualifications:STEP Certificate for Financial Services - Trusts and Estate PlanningSTEP Diploma in Trusts and Estates - England & Wales',
#   'Firm:Birketts LLP',
#   'Branch/chapter:STEP Essex',
#   'United Kingdom',
#   'United Kingdom',
#   'Profession:Lawyer/Solicitor/Attorney',
#   'STEP Qualifications:STEP Diploma in Trusts and Estates - England & Wales',
#   'Firm:Clowes & Co. LLP',
#   'Branch/chapter:STEP Manchester',
#   'Special Interest Group memberships:Digital Assets SIG',
#   'United Kingdom',
#   'United Kingdom',
#   'Profession:AccountantTax AdvisorTrustee/FiduciaryTrust OfficerWealth Management',
#   'Firm:Patrimonium',
#   'Branch/chapter:STEP Mexico',
#   'Mexico',
#   'Mexico',
#   'Profession:Lawyer/Solicitor/Attorney',
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re

# Send a GET request to the URL
url = 'https://www.step.org/directory/members/ms-gail-black-0038000000gilbgaau'
response = requests.get(url)

# Parse the HTML content using Beautiful Soup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the email element
email_element = soup.find('div', class_='field--type-email')

# Extract the encoded email address from the href attribute
email_href = email_element.a['href']
email_encoded = email_href.replace('mailto:', '')

# Decode the email address using a regular expression
email_decoded = re.sub(r'(\d+)', lambda x: chr(int(x.group(0))), email_encoded)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-87-881eeaf1bb5f> in <module>
#      18
#      19 # Decode the email address using a regular expression
# ---> 20 email_decoded = re.sub(r'(\d+)', lambda x: chr(int(x.group(0))), email_encoded)
#
# /usr/lib/python3.8/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# <ipython-input-87-881eeaf1bb5f> in <lambda>(x)
#      18
#      19 # Decode the email address using a regular expression
# ---> 20 email_decoded = re.sub(r'(\d+)', lambda x: chr(int(x.group(0))), email_encoded)
#
# OverflowError: Python int too large to convert to C int

# %%
import requests
from bs4 import BeautifulSoup
import re
url = 'https://www.step.org/directory/members/ms-gail-black-0038000000gilbgaau'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
email_element = soup.find('div', {'class': "field field--name-field-directory-email field--type-email field--label-hidden field--item"})
email_href = email_element.a['href']
email_encoded = email_href.replace('mailto:', '')
email_decoded = re.sub('(\d+)','', email_encoded)

print(email_decoded)
# Out:
# /cdn-cgi/l/email-protection#eeeceeebcedeececeffeefedfefeeaeeefed

# %%
import imaplib, email, email.parser, email.policy
import html2text
import pprint, sys

#
# Utilities for Debug
#
pp = pprint.PrettyPrinter(indent=4, width=80)

def myprint(str):
    print(str.encode('cp932','replace').decode('cp932'))


#
# search mails in IMAP
#
def search_imap():
    #mail = imaplib.IMAP4_SSL("imap.mail.com", 993)
    mail = imaplib.IMAP4_SSL("imap.mail.yahoo.co.jp")

    mail.login("sdkn104@yahoo.co.jp","xxxxxx")
    mail.list()
    mail.select('Inbox') # specify inbox
    #mail.select('register') # specify label

    #typ, [data] = mail.search(None, "UNSEEN")
    typ, [data] = mail.search(None, "(ALL)")

    print("searched")
    print(typ)
    pp.pprint(data.split())

    #check
    if typ == "OK":
        if data != '':
            print("New Mail")
        else:
            print("Non")

    # for each mail searched
    for num in data.split():
        print("START " + str(num) + "--------------------------------------------------")

        # fetch whole message as RFC822 format
        result, d = mail.fetch(num, "(RFC822)")


        # save to file
        f = open("mail_" + str(num) + ".txt","bw")
        f.write(d[0][1])
        f.close()

        print("####################################")

        msg = email2Text(d[0][1])

        print("------------------------------------")
        myprint(msg["subject"])
        myprint(msg["date"])
        myprint(msg["from"])
        myprint(msg["body"])

    # closing
    mail.close()
    mail.logout()

#
# Get subject, date, from and body as text from email RFC822 style string
#
def email2Text(rfc822mail):
        # parse the message
        msg_data = email.message_from_bytes(rfc822mail, policy=email.policy.default)
        
        mail_value = {}

        # Get From, Date, Subject
        mail_value["from"] = header_decode(msg_data.get('From'))
        mail_value["date"] = header_decode(msg_data.get('Date'))
        mail_value["subject"] = header_decode(msg_data.get('Subject'))
        
        #print( mail_value["date"] )
        #print( mail_value["from"] )
        #print( mail_value["subject"] )

        # Get Body
        #print("--- body ---")
        mail_value["body"] = ""
        if msg_data.is_multipart():
            for part in msg_data.walk():
                #print("--- part ---")
                ddd = msg2bodyText(part)
                if ddd is not None:
                    mail_value["body"] = mail_value["body"] + ddd
        else:
            #print("--- single ---")
            ddd = msg2bodyText(msg_data)
            mail_value["body"] = ddd

        return mail_value

#
# get body text from a message (EmailMessage instance)
#
def msg2bodyText(msg):
    ct = msg.get_content_type()
    cc = msg.get_content_charset() # charset in Content-Type header
    cte = msg.get("Content-Transfer-Encoding")
    print("part: " + str(ct) + " " + str(cc) + " : " + str(cte))

    # skip non-text part/msg
    if msg.get_content_maintype() != "text":
        return None

    # get text
    ddd = msg.get_content()

    # html to text
    if msg.get_content_subtype() == "html":
        try:
            ddd = html2text.html2text(ddd)
        except:
            print("error in html2text")

    return ddd


def header_decode(header):
    hdr = ""
    for text, encoding in email.header.decode_header(header):
        if isinstance(text, bytes):
            text = text.decode(encoding or "us-ascii")
        hdr += text
    return hdr 


if __name__ == "__main__":
    search_imap()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-105-eeebd78661b2> in <module>
#     135
#     136 if __name__ == "__main__":
# --> 137     search_imap()
#
# <ipython-input-105-eeebd78661b2> in search_imap()
#      19     mail = imaplib.IMAP4_SSL("imap.mail.yahoo.co.jp")
#      20
# ---> 21     mail.login("sdkn104@yahoo.co.jp","xxxxxx")
#      22     mail.list()
#      23     mail.select('Inbox') # specify inbox
#
# /usr/lib/python3.8/imaplib.py in login(self, user, password)
#     601         typ, dat = self._simple_command('LOGIN', user, self._quote(password))
#     602         if typ != 'OK':
# --> 603             raise self.error(dat[-1])
#     604         self.state = 'AUTH'
#     605         return typ, dat
#
# error: b'[AUTHENTICATIONFAILED] Incorrect username or password.'

# %%
pip install html2text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
import re
from bs4 import BeautifulSoup as bs

import sys
from PyQt5.QtWidgets import QApplication
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEnginePage

class Client(QWebEnginePage):
    def _init_(self,url):
        self.app = QApplication(sys.argv)
        QWebEnginePage._init_(self)

        self.html=""
        self.loadFinished.connect(self.on_page_load)

        self.load(QUrl(url))
        self.app.exec_()

    def on_page_load(self):
        self.html=self.toHtml(self.Callable)
        print("In on_page_load \n \t HTML: ",self.html)

    def Callable(self,html_str):
        print("In Callable \n \t HTML_STR: ",len(html_str))
        self.html=html_str
        print("In Callable \n \t HTML_STR: ",len(self.html))
        self.app.quit()

url="https://www.step.org/directory/members/mr-roger-frick-0038000000gin05aae"

client_response= Client(url)

soup = bs(client_response.html, 'html.parser')

table = soup.find_all(attrs={'class':'field field--name-field-directory-email field--type-email field--label-hidden field--item'})
#print(len(table))
table = table[len(table)-1]
#print(table)
a = table.find_all('a')
#print(len(a))
# for i in a:
#     print(i.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e2a0f3eccbd6> in <module>
#       4
#       5 import sys
# ----> 6 from PyQt5.QtWidgets import QApplication
#       7 from PyQt5.QtCore import QUrl
#       8 from PyQt5.QtWebEngineWidgets import QWebEnginePage
#
# ModuleNotFoundError: No module named 'PyQt5'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import selenium as s

# %%
pip install QApplication
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement QApplication (from versions: none)
# ERROR: No matching distribution found for QApplication

# %%
pip install PyQt5.QtWidgets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement PyQt5.QtWidgets (from versions: none)
# ERROR: No matching distribution found for PyQt5.QtWidgets

# %%
from bs4 import BeautifulSoup
import requests
url_starting = "https://www.step.org"
page = 0
url_with_page = "" #This is the url with the page number which changes every time you go to the next page


def decodeEmail(e):
    de = ""
    k = int(e[:2], 16)

    for i in range(2, len(e)-1, 2):
        de += chr(int(e[i:i+2], 16)^k)

    return de


for i in range(0, 10000):
    
    url_with_page = f"https://www.step.org/directory/members/search?f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&name=&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&{page}"
    result = requests.get(url_with_page)
    soup = BeautifulSoup(result.text, 'html.parser')
    page += 1 #increasing the page number
    #Check if there is a next page

    if soup.find_all("div", {"class": "view-empty"}) == "Sorry, your search returned no results, please widen your search. Here are some search tips to help you:":
        break #Stop if there is no next page

    else:
        for name in soup.find_all('div', {'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
            for href in name.find_all('a'):
                temp_url = href.get('href')
                r = BeautifulSoup(requests.get(f"{url_starting}"+ str(temp_url)).text, 'html.parser')
                
                #Getting name of the member
                name = r.find('div', {'class': 'field field--name-name field--type-string field--label-hidden field--item'}).get_text()
                
                #Checking if the member has a phone number
                if r.find('div', {'class': 'field field--name-field-directory-phone field--type-telephone field--label-hidden field--item'}) is not None:
                    phone = r.find('div', {'class': 'field field--name-field-directory-phone field--type-telephone field--label-hidden field--item'}).get_text()
                else:
                    phone = "Doen't have a phone number"
                
                #Checking if the member has an email
                if r.find('div', {'class': 'field field--name-field-directory-email field--type-email field--label-hidden field--item'}) is not None:
                    encoded_email = r.find("span", {'class': '__cf_email__'}).get("data-cfemail")
                    email = decodeEmail(encoded_email)
                else:
                    email = "Doesn't have an email"


                print(name, phone, email)

# %%
from bs4 import BeautifulSoup
import requests
url_starting = "https://www.step.org"
page = 0
url_with_page = "" #This is the url with the page number which changes every time you go to the next page


def decodeEmail(e):
    de = ""
    k = int(e[:2], 16)

    for i in range(2, len(e)-1, 2):
        de += chr(int(e[i:i+2], 16)^k)

    return de


for i in range(0, 10000):
    
    url_with_page = f"https://www.step.org/directory/members/search?f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&name=&0=practice_areas_members%3ACompany%20formation/management&1=practice_areas_members%3ACompliance/regulation&2=practice_areas_members%3ADispute%20resolution&3=practice_areas_members%3AFamily%20law&4=practice_areas_members%3AImmigration&5=practice_areas_members%3AInvestment&6=practice_areas_members%3ATax&7=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&8=practice_areas_members%3AValuation&9=practice_areas_members%3AWills%20and%20probate&f%5B0%5D=practice_areas_members%3AAnti-money%20laundering&f%5B1%5D=practice_areas_members%3ACompany%20formation/management&f%5B2%5D=practice_areas_members%3ACompliance/regulation&f%5B3%5D=practice_areas_members%3ADispute%20resolution&f%5B4%5D=practice_areas_members%3AFamily%20law&f%5B5%5D=practice_areas_members%3AImmigration&f%5B6%5D=practice_areas_members%3AInvestment&f%5B7%5D=practice_areas_members%3ATax&f%5B8%5D=practice_areas_members%3ATax%20Advisory%20-%20Trusts%20and%20estate%20planning&f%5B9%5D=practice_areas_members%3AValuation&f%5B10%5D=practice_areas_members%3AWills%20and%20probate&page={page}"
    result = requests.get(url_with_page)
    soup = BeautifulSoup(result.text, 'html.parser')
    page += 1 #increasing the page number
    #Check if there is a next page

    if soup.find_all("div", {"class": "view-empty"}) == "Sorry, your search returned no results, please widen your search. Here are some search tips to help you:":
        break #Stop if there is no next page

    else:
        for name in soup.find_all('div', {'class': 'field field--name-name field--type-string field--label-hidden field--item'}):
            for href in name.find_all('a'):
                temp_url = href.get('href')
                r = BeautifulSoup(requests.get(f"{url_starting}"+ str(temp_url)).text, 'html.parser')
                
                #Getting name of the member
                name = r.find('div', {'class': 'field field--name-name field--type-string field--label-hidden field--item'}).get_text()
                
                #Checking if the member has a phone number
                if r.find('div', {'class': 'field field--name-field-directory-phone field--type-telephone field--label-hidden field--item'}) is not None:
                    phone = r.find('div', {'class': 'field field--name-field-directory-phone field--type-telephone field--label-hidden field--item'}).get_text()
                else:
                    phone = "Doen't have a phone number"
                
                #Checking if the member has an email
                if r.find('div', {'class': 'field field--name-field-directory-email field--type-email field--label-hidden field--item'}) is not None:
                    encoded_email = r.find("span", {'class': '__cf_email__'}).get("data-cfemail")
                    email = decodeEmail(encoded_email)
                else:
                    email = "Doesn't have an email"


                print(name, phone, email)
# Out:
# Miss Melanie Pratlett +44 (0)1799 523441 m.pratlett@adams-harrison.co.uk
# Mr Jean Turcotte +1 514 879 2039 jean.turcotte@sunlife.com
# Mrs Parveen Haynes +44 1494 781840 parveen.haynes@lennonssolicitors.co.uk
# Mr Richard Heberden Doen't have a phone number richard.heberden@sjpp.co.uk
# Ms Kenny Gbaja Sofowora Doen't have a phone number Doesn't have an email
# Mr Ray Loucks +1 604 646 3378 rloucks@bdo.ca
# Dr Giangiacomo Bausone +39 328 425 3626 law.firmbsns@yahoo.com
# Ms Karen Stewart +44 1560 525104 kstewart@mackwylie.com
# Mrs Susan Swift +44 (0)146 324 6300 susie.swift@saffery.com
# Mr Anthony Page +44 (0)1624 631710 anthony@khtlimited.com
# Mr Steven Giacona +1 212 257 4368 steven@roundtableservices.com
# Mrs Susan Mehinagic Doen't have a phone number Doesn't have an email
# Mr Arnaud Jouanjan 0033613 211239 arnaud@jouanjan.com
# Mr Sean Cockburn +44 (0)131 313 7922 sean.cockburn@mazars.co.uk
# Mr Paul Ferrara +1 212-852-2817 paul.a.ferrara@bofa.com
# ...

# %%
import pandas as pd
df=pd.read_html('https://www.worldometers.info/world-population/azerbaijan-population/',attrs={'class':"table table-striped table-bordered table-hover table-condensed table-list"})

# %%
df
# Out:
# [    Year  Population Yearly % Change  Yearly Change  Migrants (net)  \
#  0   2020    10139177          0.91 %          91459            1200
#  1   2019    10047718          0.99 %          98181            1200
#  2   2018     9949537          1.06 %         104217            1200
#  3   2017     9845320          1.12 %         109277            1200
#  4   2016     9736043          1.18 %         113298            1200
#  5   2015     9622745          1.27 %         118057            1700
#  6   2010     9032461          1.13 %          98771           10716
#  7   2005     8538605          1.00 %          83173            7305
#  8   2000     8122741          0.88 %          69463          -22370
#  9   1995     7775424          1.43 %         106533          -23023
#  10  1990     7242761          1.67 %         115263          -32314
#  11  1985     6666447          1.62 %         103143          -20314
#  12  1980     6150733          1.63 %          95320          -10093
# ...
