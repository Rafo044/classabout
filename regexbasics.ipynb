# %%
import re

# %%
l=[]
soyad=str(input('Soyadinizi daxil edin : '))
sfilter=re.search('[A-Z]\w*[a-z]$',soyad)
if sfilter:
  ad=str(input('Adinizi daxil edin : '))
  afilter=re.search('[A-Z]\w*[a-z]$',ad)
  if afilter:
    number=input('Nomrenizi daxil edin  : ')
    nfilter=re.search('^994(77|50|99|10|55|51)[0-9]',number)
    if len(number)==12 and nfilter:
      poct=input('Elektron poct unvaniniz : ')
      pfilter=re.search('@gmail.com$',poct)
      if pfilter:
        siyahi={number:[ad,soyad,poct]}
        l.append(siyahi)
        print(l)
      else:
        print('Poctunuzu yanlish daxil etdiniz')
    else:
      print('Nomrenizi yanlish daxil etdiniz')
  else:
    print('Ad boyuk heriflerle yazilmalidir')
else:
  print('Soyad boyuk herifle baslamalidir,sonra ise kicik herflerle yazilmalidir')
# Out:
# Soyadinizi daxil edin : Sdfghj
# Adinizi daxil edin : Asdfgh
# Nomrenizi daxil edin  : 994504760772
# Elektron poct unvaniniz : as@gmail.com
# [{'994504760772': ['Asdfgh', 'Sdfghj', 'as@gmail.com']}]
