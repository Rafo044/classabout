# %%
account=str(input('Istifadechi adi daxil edin : '))
parol=int(input('Parol yaradin : '))
nomre=int(input('Nomrenizi daxil edin : '))
nomre_siyahisi=[]
def nomre_duzgunluyu():
  nomre_siyahisi.append(nomre)
  nomre_yoxlama=int(input('Nomrenizin duzgunluyunu yoxlayin : '))
  for z in nomre_siyahisi:
    if nomre_yoxlama==z:
      print('Nomreniz dogrudur')
    else:
      print('Nomreni duzgun daxil edin :  ')
alish=22
satish=90
faiz=44
balans=50
sebet=[]
def medaxil():
  yukle=int(input('Medaxili daxiol edin :'))
  balans=balans+yukle
  print(f"emeliyyat ugurla basha chatdi.Sizin balansiniz  : {balans}")
database={account: [satish,alish,faiz,balans]}
mehsullar={'a': 50,'b': 42,'c':55,'d':38}
print(f' Mehsullarin siyahisi  {mehsullar} ')
secim=str(input('Almaq istediyiniz mehsulu daxil edin  : '))
for x in mehsullar:
  if x=='a':
    print('Qiymeti : ',50)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':#dictionary ile keys,valueni birbasha yaza bilmedim
      sebet.append('a')
      print(f'Satish  : {satish+50} ,Alish : {alish} , Faiz : {faiz}, Balans : {balans-50}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  elif x=='b':
    print('Qiymeti : ',42)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':
      sebet.append('b')
      print(f'Satish  : {satish+42} ,Alish : {alish} , Faiz : {faiz}, Balans : {balans-42}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  elif x=='c':
    print('Qiymeti : ',55)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':
      sebet.append('a')
      print(f'Satish  : {satish+55} ,Alish : {alish} , Faiz : {faiz}, Balans : {balans-55}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  elif x=='d':
    print('Qiymeti : ',38)
    almaq=str(input('Almaq isteyirsinizmi? '))
    if almaq=='beli':
      sebet.append('a')
      print(f'Satish  : {satish+38} ,Alish : {alish} , Faiz : {faiz}, Balans : {balans-38}')
    elif almaq=='xeyir':
      print('Diger mehsullara kechid edin  : ')
    else:
      print('Yanlish sechim')
  else:
    print('Yanlish mehsul sechildi')
# Out:
#  Mehsullarin siyahisi  {'a': 50, 'b': 42, 'c': 55, 'd': 38}
# Qiymeti :  50

# %%
database
# Out:
# {'user01': ['satish', 'borc', 'alish', 'nagdlashdirma'], 'cvb': [0, 0, 0, 0]}
