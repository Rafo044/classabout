# %%
#Girish- Malqebulu

# %%
class a:
  def __init__(self,market):
    self.market=market
  def mal_qebulu(self):
    self.barkod=int(input('barkodu daxil edin'))
    self.mehsul_adi=str(input('Mehsulun adini daxil edin'))
    self.sayi=int(input('Sayi daxil edin'))
  def anbar(self):
    self.stok={self.barkod :[self.mehsul_adi,self.sayi]}
  def kassa(self):
    self.skaner=int(input('Barkodu oxudun : '))
    for a in stok:
      if self.skaner==self.barkod:
        miqdar=int(input('Miqdari daxil edin'))
        if miqdar>sayi:
          print('Anbardaki mehsuldan coxdur')
        print(f' Mehsulun barkodu : {self.barkod}, Mehsulun adi : {self.mehsul_adi}, Stokda mehsulun qalan sayi : {self.sayi-miqdar} ')
      else:
        print('Duzgun barkodu daxil edin')

# %%
x=a("xmarket")

# %%
x.mal_qebulu()

# %%
x.anbar()

# %%
x.kassa()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x.kassa()
#
# Cell In[9], line 12, in a.kassa(self)
#      10 def kassa(self):
#      11   self.skaner=int(input('Barkodu oxudun : '))
# ---> 12   for a in stok:
#      13     if self.skaner==self.barkod:
#      14       miqdar=int(input('Miqdari daxil edin'))
#
# NameError: name 'stok' is not defined
